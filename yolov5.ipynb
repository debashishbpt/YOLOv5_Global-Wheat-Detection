# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 3106 (delta 4), reused 1 (delta 1), pack-reused 3091
# Receiving objects: 100% (3106/3106), 6.73 MiB | 21.74 MiB/s, done.
# Resolving deltas: 100% (2055/2055), done.

# %%
# !nvidia-smi
# Out:
# Thu Nov 26 20:44:54 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   53C    P0    29W /  70W |    227MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import tensorflow as tf 
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !pip install -U PyYAML
# Out:
# ...
#      |████████████████████████████████| 276kB 8.7MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=d46631add656cfcbd3b5981bfdfe5c688fe2b68aa7aeaa36db5f5d03dacef403
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built PyYAML
# ...
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !python train.py --img 1024 --batch 8 --epochs 100 --data wheat.yaml --cfg models/yolov5s.yaml --name wm
# Out:
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079MB)
#
# Namespace(adam=False, batch_size=8, bucket='', cache_images=False, cfg='models/yolov5s.yaml', data='wheat.yaml', device='', epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[1024, 1024], local_rank=-1, log_imgs=16, multi_scale=False, name='wm', noautoanchor=False, nosave=False, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/wm', single_cls=False, sync_bn=False, total_batch_size=8, weights='yolov5s.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2020-11-26 20:49:20.258385: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !tensorboard --logdir=runs

# %%
# %ls
# Out:
# data/       LICENSE        README.md         train.py        wheat_data/
# detect.py   models/        requirements.txt  tutorial.ipynb  wheat.yaml
# Dockerfile  munge_data.py  runs/             utils/          yolov5s.pt
# hubconf.py  __pycache__/   test.py           weights/

# %%
# !python detect.py --source /content/yolov5/wheat_data/images/validation --weights /content/yolov5/runs/train/wm/weights/best.pt
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/yolov5/wheat_data/images/validation', update=False, view_img=False, weights=['/content/yolov5/runs/train/wm/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079MB)
#
# Fusing layers...
# Model Summary: 232 layers, 7246518 parameters, 0 gradients
# image 1/338 /content/yolov5/wheat_data/images/validation/013669953.jpg: 640x640 23 wheats, Done. (0.013s)
# image 2/338 /content/yolov5/wheat_data/images/validation/015939012.jpg: 640x640 55 wheats, Done. (0.013s)
# image 3/338 /content/yolov5/wheat_data/images/validation/02992044c.jpg: 640x640 24 wheats, Done. (0.013s)
# image 4/338 /content/yolov5/wheat_data/images/validation/02d662fa8.jpg: 640x640 84 wheats, Done. (0.013s)
# ...

# %%
import shutil
shutil.make_archive('yolov5', 'zip', 'yolov5')
# Out:
# '/content/yolov5.zip'
